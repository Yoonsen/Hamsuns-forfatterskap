# %%
import dhlab as dh
import pandas as pd

# %%
c = dh.Corpus(author="hamsun knut", title="benoni", from_year=1990).frame

# %%
d = dh.Corpus(author="hamsun knut", title="livet lever", from_year=1990).frame

# %%
c
# Out:
#      dhlabid                                     urn  \
# 0  100505665     URN:NBN:no-nb_digibok_2007062500082
# 1  100450571     URN:NBN:no-nb_digibok_2008102100047
# 2  100644026  URN:NBN:no-nb_pliktmonografi_000004117
# 3  100513320     URN:NBN:no-nb_digibok_2010080620005
# 4  100216482     URN:NBN:no-nb_digibok_2009070904019
# 5  100205038     URN:NBN:no-nb_digibok_2014051908062
# 6  100544653     URN:NBN:no-nb_digibok_2011062708041
# 7  100184696     URN:NBN:no-nb_digibok_2008020501024
# 8  100386082     URN:NBN:no-nb_digibok_2019020807507
# 9  100542044     URN:NBN:no-nb_digibok_2011061509079
#
#                                                title  \
# 0                                             Benoni
# 1  Samlede verker . B. 5 : Benoni ; Rosa ; En van...
# 2                                             Benoni
# 3  Samlede verker . B. 5 : Benoni ; Rosa ; En van...
# 4                                     Benoni : Roman
# 5  Samlede verker . 5 : Benoni ; Rosa ; En vandre...
# ...

# %%
d
# Out:
#      dhlabid                                  urn  \
# 0  100223293  URN:NBN:no-nb_digibok_2014090108102
# 1  100230700  URN:NBN:no-nb_digibok_2014100908095
# 2  100260792  URN:NBN:no-nb_digibok_2015070908103
# 3  100450528  URN:NBN:no-nb_digibok_2008101704037
# 4  100164978  URN:NBN:no-nb_digibok_2013080608104
# 5  100514345  URN:NBN:no-nb_digibok_2010080620012
# 6  100500938  URN:NBN:no-nb_digibok_2007110801011
#
#                                       title  \
# 0                           Men livet lever
# 1                           Men livet lever
# 2  Samlede verker . B. 15 : Men livet lever
# 3  Samlede verker . B. 12 : Men livet lever
# 4     Samlede verker . 12 : Men livet lever
# 5  Samlede verker . B. 12 : Men livet lever
# 6                   Men livet lever : roman
#
#                                authors                                oaiid  \
# 0                        Hamsun , Knut  oai:nb.bibsys.no:990205083954702202
# ...

# %%
concs = dh.Concordance(corpus=["URN:NBN:no-nb_digibok_2011062708041"], query="Gilbert")

# %%
concs1 = dh.Concordance(corpus=["URN:NBN:no-nb_digibok_2013080608104"], query="åse")

# %%
concs.frame.concordance.to_numpy()
# Out:
# array(['Krambodsvennene og <b>Gilbert</b> lapp og kundene stod undrende stille og Hartvigsen så det godt , han gjorde seg høytidelig og... ',
#        'Og nu skal De virkelig ikke være redd for <b>Gilbert</b> lapp mere . Nei , svarte hun og rystet på... ',
#        '... god pisk og viste henne hvorledes han ville tukte <b>Gilbert</b> lapp . Det var i skogen ved møllen . Jeg... ',
#        'Benoni svarte ikke mere enn som et uvisst nei . Hun skal ha prokuratoren , sa <b>Gilbert</b> leende .',
#        '<b>Gilbert</b> svarer høytidelig ja .',
#        'Den <b>Gilbert</b> skal jeg gjerne påta meg å gjøre uskadelig , sa jeg begeistret . Jeg vet noe om ham... ',
#        'Da vagger <b>Gilbert</b> lapp på hodet , at Hartvigsen var blitt allmektig og kan hva han bare vil . Det... ',
#        'Da Benoni satte brennevin frem og bydde en dram sa <b>Gilbert</b> :',
#        'Benoni reiste seg , stod rett foran <b>Gilbert</b> og sa :',
# ...

# %%
concs1.frame.concordance.to_numpy()
# Out:
# array(['... Men han blir hverken halt eller stivbenet , det sa ho <b>Åse</b> også . Et benbrudd det er ingenting i... ',
#        '... August fik hele hændelsen med <b>Åse</b> , tilsist gråt ikke fruen mere men bare fortalte . Det syntes å lette... ',
#        '... Det er <b>Åse</b> <b>Åse</b> som står der , står og møter sauene , slår ut med aimene , vifter med... ',
#        '... Er det du , <b>Åse</b> ? sa han . Ja , svarte hun . Hvad du vil mig ? spurte... ',
#        '... hissige og får nattur på alle de ser , ja om det så er ho <b>Åse</b> , hører jeg .',
#        '... Han støtte på <b>Åse</b> en kveld nys , og han tænkte straks at han vilde høre hendes mening om pengene... ',
#        '... Hun hadde holdt hans stok i fanget , hun hadde seiv sagt at han spilte nydelig <b>Åse</b> stiger ut fra... ',
#        '... Jeg synes synd i dig , <b>Åse</b> , men fortryt ikke på at jeg ler når jeg ser dig ,... ',
# ...
